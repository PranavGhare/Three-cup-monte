# %% [markdown]
# ***Three cup monty***

# %%
#Game list 
mylist = [' ', ' ', 'O']

# %%
#shuffle list
from random import shuffle

# %%
# function for shuffle list

def shuffle_list(mylist):
    shuffle(mylist) 
    return mylist

# %%
result = shuffle_list(mylist)

# %%
# Player guess

def player_guess():

    guess = ''

    while guess not in ['0','1','2']:
        guess = input('enter no 0,1 0r 2 ')
    return int(guess)

# %%
myindex = player_guess()
# Out:
# enter no 0,1 0r 2  2

# %%
myindex
# Out:
# 2

# %%
# Checking player guess

def guess_check(mylist,guess):
    if mylist[guess] == 'O':
        print ('YOU WON!')
    else:
        print('WRONG GUESS')
        print(mylist)

# %%
# SCRIPT

#initial list
mylist = [' ',' ', 'O']

#shuffle list
shuffled_list = shuffle_list(mylist)

#player guess
guess = player_guess()


#check the guess
guess_check(shuffled_list,guess)
# Out:
# enter no 0,1 0r 2  2
# YOU WON!
